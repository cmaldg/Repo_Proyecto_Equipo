# %%
import pandas as pd

df = pd.read_csv("base_oficial_completa.csv", sep=';')
print(df)
# Out:
#     nombres_nominados_nominadas     genero          lugar_de_nacimiento  \
# 0                  Janet Gaynor   Femenino   Filadelfia, Estados Unidos
# 1           Richard Barthelmess  Masculino   Nueva York, Estados Unidos
# 2                 Emil Jannings  Masculino             Rorschach, Suiza
# 3           Richard Barthelmess  Masculino   Nueva York, Estados Unidos
# 4                 Emil Jannings  Masculino             Rorschach, Suiza
# ..                          ...        ...                          ...
# 970              Jessie Buckley   Femenino           Killarney, Irlanda
# 971                  Rose Byrne   Femenino           Balmain, Australia
# 972                 Kate Hudson   Femenino  Los Ángeles, Estados Unidos
# 973              Renate Reinsve   Femenino         Solbergelva, Noruega
# 974                  Emma Stone   Femenino   Scottsdale, Estados Unidos
#
#      nacionalidad_1 nacionalidad_2 raza_o_etnia su_debut_fue_estadounidense  \
# ...
