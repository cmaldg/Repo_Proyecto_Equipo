# %%
import pandas as pd

nombre_archivo = "Datos_limpios_Demografia_Premios_Oscar_1929-2026.csv"
df = pd.read_csv("Datos_limpios_Demografia_Premios_Oscar_1929-2026.csv")
df.head(5)
# Out:
#   nombres_nominados_nominadas     genero         lugar_de_nacimiento  \
# 0         Richard Barthelmess  Masculino  Nueva York, Estados Unidos
# 1         Richard Barthelmess  Masculino  Nueva York, Estados Unidos
# 2               Emil Jannings  Masculino            Rorschach, Suiza
# 3               Emil Jannings  Masculino            Rorschach, Suiza
# 4              Louise Dresser   Femenino  Evansville, Estados Unidos
#
#    nacionalidad_1 nacionalidad_2 raza_o_etnia su_debut_fue_estadounidense  \
# 0  Estadounidense      No aplica       Blanca                          Sí
# 1  Estadounidense      No aplica       Blanca                          No
# 2           Suiza        Alemana       Blanca                          No
# 3           Suiza        Alemana       Blanca                          No
# 4  Estadounidense      No aplica       Blanca                          Sí
#
#   titulo_original_pelicula_debut categoria_nominacion_oscar  \
# ...
